# %%
im

# %%
import seaborn as sns
import pandas as pd

# Sample DataFrame
data = pd.DataFrame({
    'Population': [1000, 2000, 3000, 4000, 5000],
    'Income': [30, 50, 60, 80, 100],
    'Profits': [5, 15, 25, 35, 45],
    'Sales': [100, 200, 300, 400, 500]
})

# Pair Plot
sns.pairplot(data)
